# %%
import numpy as np
import pandas as pd
import xarray as xr
# %pip install cpmpy
import cpmpy as cp
import os
import math

# %% [markdown]
# # old

# %%
def initial_setup(folder_name = 'Experiments/Experiment 1', model_names = ['CatBoostRegressor'], date = '2024-07-26', size=100):
    inference_graphs_dir = f'{folder_name}/Inference_Graphs'
    all_product_paths = []

    for model_name in model_names:
        base_path = os.path.join(inference_graphs_dir, model_name, date)
        if not os.path.exists(base_path):
            print(f"Path does not exist: {base_path}")
            continue
        
        all_product_paths.extend([(product_id, os.path.join(base_path, product_id)) 
                                  for product_id in os.listdir(base_path) 
                                  if product_id.isdigit()])

    sorted_product_paths = sorted(all_product_paths)
    
    sku_map = pd.read_csv('data/sku_product_name_map.csv')
    national_price_df = pd.read_csv('s3://elektra-data/commercial_comments/national_price_20240722.csv',index_col=0)

    data = {
        'prices': [], 'revenue': [], 'cost': [], 'demand': [],
        'product_ids': [], 'national_price_creditA': [], 'national_price_cashA': [],
        'national_price_DE': [], 'margin': [], 'min_credit_A': [], 'max_credit_A': [],
        'price_segment_cluster': []
    }

    for product_id, product_dir in sorted_product_paths:
        csv_file = os.path.join(product_dir, f'{date}_uncertainty_metrics.csv')
        if not os.path.exists(csv_file):
            continue

        df = pd.read_csv(csv_file)[:size]
        df = df.astype({'Price Credit': int, 'Price Cash': int, 'Credit Prediction': int, 'Credit Pred Revenue': int})

        data['prices'].append([list(pair) for pair in zip(df['Price Credit'], df['Price Cash'])])
        data['revenue'].append(df['Credit Pred Revenue'].tolist())
        data['demand'].append(df['Credit Prediction'].tolist())
        data['cost'].append(abs(df['Cost of Sale Credit']).astype(int).tolist())
        data['product_ids'].append(product_id)

        product_national_price = national_price_df[national_price_df['SKU'] == int(product_id)].iloc[0]
        
        data['national_price_creditA'].append(int(product_national_price['Control Credit Precio A']))
        data['national_price_cashA'].append(int(product_national_price['Control Cash Precio A']))
        data['national_price_DE'].append(int(product_national_price['Control Precio DE ($)']))
        data['min_credit_A'].append(int(df['Price Credit'].min()))
        data['max_credit_A'].append(int(df['Price Credit'].max()))
        data['price_segment_cluster'].append(product_national_price['price_segment'])
        data['margin'].append(int((df['Price Credit'].mean() - df['Cost of Sale Credit'].mean()) / df['Price Credit'].mean()))

    price_pair_options = list(range(1, 101))

    xr_data = {
        'prices_xr': xr.DataArray(data['prices'], dims=["product", "price_pair_option", "price"], 
                               coords={"cluster": ("product", data['price_segment_cluster']),
                                       "product": data['product_ids'],
                                       "price_pair_option": price_pair_options}, name="Prices"),
        'demands_xr': xr.DataArray(data['demand'], dims=["product", "price_pair_option"], 
                                coords={"product": data['product_ids'], "price_pair_option": price_pair_options}, name="Demands"),
        'costs_xr': xr.DataArray(data['cost'], dims=["product", "price_pair_option"], 
                              coords={"product": data['product_ids']}, name="Costs"),
        'revenues_xr': xr.DataArray(data['revenue'], dims=["product", "price_pair_option"], 
                                 coords={"product": data['product_ids'], "price_pair_option": price_pair_options}, name="Revenues"),
        'national_price_creditA_xr': xr.DataArray(data['national_price_creditA'], dims=["product"], 
                                               coords={"product": data['product_ids']}, name="NationalPriceCreditA"),
        'national_price_cashA_xr': xr.DataArray(data['national_price_cashA'], dims=["product"], 
                                             coords={"product": data['product_ids']}, name="NationalPriceCashA"),
        'national_price_DE_xr': xr.DataArray(data['national_price_DE'], dims=["product"], 
                                          coords={"product": data['product_ids']}, name="NationalPriceDE"),
        'min_price_creditA_xr': xr.DataArray(data['min_credit_A'], dims=["product"], 
                                          coords={"product": data['product_ids']}, name="MinPriceCreditA"),
        'max_price_creditA_xr': xr.DataArray(data['max_credit_A'], dims=["product"], 
                                          coords={"product": data['product_ids']}, name="MaxPriceCreditA"),
        'margin_xr': xr.DataArray(data['margin'], dims=["product"], 
                               coords={"product": data['product_ids']}, name="Margins")
    }

    return xr_data

def define_model(xr_data):    
    num_products, num_price_pairs = xr_data['prices_xr'].shape[0], xr_data['prices_xr'].shape[1]
    price_indices = cp.intvar(0, num_price_pairs-1, shape=(num_products,), name='price_indices')
    model = cp.Model()

    add_revenue_objective(model, xr_data['revenues_xr'], price_indices)
    add_constraints(model, xr_data, price_indices)

    return model, price_indices


def add_revenue_objective(model: cp.Model, revenues_xr, price_indices):
    total_revenue = sum(
        cp.Element(revenues_xr.values[p, :], price_indices[p])
        for p in range(revenues_xr.shape[0])
    )
    model.maximize(total_revenue)

def add_constraints(model: cp.Model, xr_data, price_indices):
    for product in xr_data['prices_xr'].product.values:
        product_idx = xr_data['prices_xr'].get_index('product').get_loc(product)
        national_price_creditA = xr_data['national_price_creditA_xr'].sel(product=product).values
        national_price_DE = xr_data['national_price_DE_xr'].sel(product=product).values

        model += (cp.Element(xr_data['prices_xr'].sel(product=product, price=0).values,
                             price_indices[product_idx]) * 100 < national_price_DE * 100)

    price_segments = xr_data['prices_xr'].coords['cluster'].values
    unique_segments = np.unique(price_segments)

    for segment in unique_segments:
        segment_products = xr_data['prices_xr'].where(xr_data['prices_xr'].coords['cluster'] == segment, drop=True)
        segment_margins = xr_data['margin_xr'].where(xr_data['prices_xr'].coords['cluster'] == segment, drop=True)

        sorted_indices = np.argsort(-segment_margins.values)
        sorted_products = segment_products.isel(product=sorted_indices)

        if segment != 10:
            top_30_percent_index = int(len(sorted_products.product) * 0.3)
            top_30_products = sorted_products.isel(product=slice(0, top_30_percent_index))
            remaining_70_products = sorted_products.isel(product=slice(top_30_percent_index, None))

            add_price_constraints(model, xr_data, price_indices, top_30_products, 90, 100)
            add_price_constraints(model, xr_data, price_indices, remaining_70_products, 97, 102)
        else:
            add_price_constraints(model, xr_data, price_indices, sorted_products, 90, 100)

def add_price_constraints(model, xr_data, price_indices, products, lower_percent, upper_percent):
    for product in products.product.values:
        product_idx = xr_data['prices_xr'].get_index('product').get_loc(product)
        national_price_creditA = xr_data['national_price_creditA_xr'].sel(product=product).values
        price_element = cp.Element(xr_data['prices_xr'].sel(product=product, price=0).values,
                                   price_indices[product_idx]) 

        model += (price_element * 100 <= national_price_creditA * upper_percent )
        model += (price_element * 100 >= national_price_creditA * lower_percent )

def solve_model(model: cp.Model, price_indices, xr_data):  
    result = model.solve()
    
    if result:
        solution = pd.DataFrame(columns=['Product','Catalan Credit A','Catalan Cash A','National Credit A','National Cash A','National DE','Min Credit A','Max Credit A','Demand','Revenue'])

        
        print("Optimal total Revenue found:", model.objective_value())
        for p in range(xr_data['prices_xr'].shape[0]):
            price_index = price_indices[p].value()
            best_price_pair = xr_data['prices_xr'][p, price_index, :].values
            credit_A = xr_data['prices_xr'][p, price_index, 0].values
            cash_A = xr_data['prices_xr'][p, price_index, 1].values
            revenue = xr_data['revenues_xr'][p, price_index].values
            demand = xr_data['demands_xr'][p, price_index].values
            # cluster = prices_xr.coords['cluster'].values[p]
            product = xr_data['prices_xr'].coords['product'].values[p]
            natinal_credit_price = xr_data['national_price_creditA_xr'].sel(product=product).values
            natinal_cash_price = xr_data['national_price_cashA_xr'].sel(product=product).values
            min_credit_price = xr_data['min_price_creditA_xr'].sel(product=product).values
            max_credit_price = xr_data['max_price_creditA_xr'].sel(product=product).values
            national_DE_price = xr_data['national_price_DE_xr'].sel(product=product).values
            print(f" Product {product}: Best Price Pair Index {price_index}, Prices: {best_price_pair}, Revenue: {revenue}, Demand: {demand}")
        
            new_row = pd.DataFrame([[
                                        product,
                                        credit_A,
                                        cash_A,
                                        # best_price_pair,
                                        natinal_credit_price,
                                        natinal_cash_price,
                                        national_DE_price,
                                        min_credit_price,
                                        max_credit_price,
                                        demand,
                                        revenue
                                            ]], columns=['Product','Catalan Credit A','Catalan Cash A','National Credit A','National Cash A','National DE','Min Credit A','Max Credit A','Demand','Revenue'])
            solution = pd.concat([solution,new_row], ignore_index=True)
        
        solution.to_csv('Solution4.csv')
        
        
        return solution
    else:
    
        print("No solution found. Performing infeasibility analysis...")
        
        
        return None

def perform_ILP():
    
    prices_xr, demands_xr, costs_xr, revenues_xr = generate_data_xarray(5,4,20)
    model, price_indices = define_model(prices_xr, revenues_xr, costs_xr, demands_xr)
    
    solution_df = solve_model(model, price_indices, prices_xr, revenues_xr)
    return solution_df

# prices_xr, demands_xr, costs_xr, revenues_xr, national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, min_price_creditA_xr, max_price_creditA_xr, margin_xr = initial_setup()
xr_data = initial_setup(folder_name = 'Experiments/Experiment 1', model_names = ['CatBoostRegressor'], date = '2024-07-26', size=100)
model, price_indices = define_model(xr_data)

# model, price_indices = define_model(xr_data['prices_xr'], xr_data['revenues_xr'], xr_data['costs_xr'], xr_data['demands_xr'],xr_data['national_price_creditA_xr'], xr_data['national_price_cashA_xr'], xr_data['national_price_DE_xr'], xr_data['margin_xr'],xr_data)
# solution_df = solve_model(model, price_indices, xr_data['prices_xr'], xr_data['revenues_xr'],xr_data['demands_xr'],xr_data['national_price_creditA_xr'], xr_data['national_price_cashA_xr'], xr_data['min_price_creditA_xr'], xr_data['max_price_creditA_xr'],xr_data['national_price_DE_xr'])
solution_df = solve_model(model, price_indices, xr_data)
# Out:
# Optimal total Revenue found: 790507
#  Product 31030392: Best Price Pair Index 50, Prices: [1080 1080], Revenue: 750, Demand: 1
#  Product 31032647: Best Price Pair Index 20, Prices: [1774 1774], Revenue: 1213, Demand: 2
#  Product 31036667: Best Price Pair Index 57, Prices: [1020 1020], Revenue: 3268, Demand: 8
#  Product 31041272: Best Price Pair Index 56, Prices: [1221 1221], Revenue: 305, Demand: 1
#  Product 31043249: Best Price Pair Index 17, Prices: [783 783], Revenue: 0, Demand: 0
#  Product 31044050: Best Price Pair Index 50, Prices: [2700 2700], Revenue: 500, Demand: 1
#  Product 31044759: Best Price Pair Index 41, Prices: [2189 2189], Revenue: 0, Demand: 0
#  Product 31044766: Best Price Pair Index 56, Prices: [2595 2595], Revenue: 305, Demand: 1
#  Product 31044773: Best Price Pair Index 56, Prices: [1985 1985], Revenue: 315, Demand: 1
#  Product 31044774: Best Price Pair Index 41, Prices: [1897 1897], Revenue: 0, Demand: 0
#  Product 31044891: Best Price Pair Index 56, Prices: [732 732], Revenue: 297, Demand: 1
#  Product 31044904: Best Price Pair Index 50, Prices: [1649 1649], Revenue: 330, Demand: 1
#  Product 31045043: Best Price Pair Index 50, Prices: [5099 5099], Revenue: 728, Demand: 1
#  Product 31045187: Best Price Pair Index 41, Prices: [2218 2218], Revenue: 0, Demand: 0
#  Product 31045254: Best Price Pair Index 56, Prices: [2290 2290], Revenue: 610, Demand: 2
#  Product 31045265: Best Price Pair Index 56, Prices: [891 891], Revenue: 361, Demand: 1
#  Product 31045268: Best Price Pair Index 56, Prices: [2290 2290], Revenue: 327, Demand: 1
#  Product 31045301: Best Price Pair Index 56, Prices: [1985 1985], Revenue: 3054, Demand: 5
#  Product 31045304: Best Price Pair Index 56, Prices: [1099 1099], Revenue: 381, Demand: 1
#  Product 31047340: Best Price Pair Index 56, Prices: [1995 1995], Revenue: 407, Demand: 1
#  Product 31047401: Best Price Pair Index 56, Prices: [732 732], Revenue: 333, Demand: 1
#  Product 31047427: Best Price Pair Index 56, Prices: [1991 1991], Revenue: 1076, Demand: 2
#  Product 31047746: Best Price Pair Index 50, Prices: [1260 1260], Revenue: 360, Demand: 1
#  Product 31047788: Best Price Pair Index 56, Prices: [2137 2137], Revenue: 7905, Demand: 22
#  Product 31047799: Best Price Pair Index 56, Prices: [1795 1795], Revenue: 354, Demand: 1
#  Product 31047800: Best Price Pair Index 56, Prices: [1795 1795], Revenue: 327, Demand: 1
#  Product 31047831: Best Price Pair Index 56, Prices: [1525 1525], Revenue: 448, Demand: 1
#  Product 31047852: Best Price Pair Index 56, Prices: [1526 1526], Revenue: 305, Demand: 1
#  Product 31047853: Best Price Pair Index 41, Prices: [1459 1459], Revenue: 0, Demand: 0
#  Product 31047854: Best Price Pair Index 56, Prices: [1526 1526], Revenue: 305, Demand: 1
#  Product 31047886: Best Price Pair Index 57, Prices: [765 765], Revenue: 306, Demand: 1
#  Product 31047888: Best Price Pair Index 56, Prices: [1374 1374], Revenue: 361, Demand: 1
#  Product 31047890: Best Price Pair Index 56, Prices: [2137 2137], Revenue: 328, Demand: 1
#  Product 31047968: Best Price Pair Index 41, Prices: [963 963], Revenue: 0, Demand: 0
#  Product 31047969: Best Price Pair Index 56, Prices: [1007 1007], Revenue: 420, Demand: 1
#  Product 31048002: Best Price Pair Index 50, Prices: [3299 3299], Revenue: 1249, Demand: 2
#  Product 31048023: Best Price Pair Index 56, Prices: [2015 2015], Revenue: 1145, Demand: 3
#  Product 31048066: Best Price Pair Index 41, Prices: [2130 2130], Revenue: 0, Demand: 0
#  Product 31048227: Best Price Pair Index 41, Prices: [828 828], Revenue: 0, Demand: 0
#  Product 31048290: Best Price Pair Index 56, Prices: [2244 2244], Revenue: 291, Demand: 1
#  Product 31048298: Best Price Pair Index 56, Prices: [2543 2543], Revenue: 339, Demand: 1
#  Product 31048299: Best Price Pair Index 56, Prices: [2543 2543], Revenue: 1696, Demand: 3
#  Product 31048389: Best Price Pair Index 56, Prices: [3358 3358], Revenue: 671, Demand: 1
#  Product 31048641: Best Price Pair Index 56, Prices: [1679 1679], Revenue: 373, Demand: 1
#  Product 31048650: Best Price Pair Index 41, Prices: [1605 1605], Revenue: 0, Demand: 0
#  Product 31048828: Best Price Pair Index 56, Prices: [2543 2543], Revenue: 508, Demand: 1
#  Product 31048830: Best Price Pair Index 56, Prices: [2543 2543], Revenue: 811, Demand: 2
#  Product 31048865: Best Price Pair Index 56, Prices: [2527 2527], Revenue: 766, Demand: 1
#  Product 31048866: Best Price Pair Index 56, Prices: [2527 2527], Revenue: 754, Demand: 1
#  Product 31049136: Best Price Pair Index 56, Prices: [2595 2595], Revenue: 341, Demand: 1
#  Product 31049532: Best Price Pair Index 41, Prices: [661 661], Revenue: 0, Demand: 0
#  Product 31049533: Best Price Pair Index 56, Prices: [692 692], Revenue: 618, Demand: 1
#  Product 31049642: Best Price Pair Index 56, Prices: [1221 1221], Revenue: 2290, Demand: 3
#  Product 31050108: Best Price Pair Index 57, Prices: [612 612], Revenue: 612, Demand: 2
#  Product 31050109: Best Price Pair Index 57, Prices: [612 612], Revenue: 3063, Demand: 4
#  Product 31050111: Best Price Pair Index 56, Prices: [885 885], Revenue: 351, Demand: 1
#  Product 31050112: Best Price Pair Index 56, Prices: [885 885], Revenue: 681, Demand: 2
#  Product 31050114: Best Price Pair Index 56, Prices: [1068 1068], Revenue: 4073, Demand: 8
#  Product 31050115: Best Price Pair Index 56, Prices: [1068 1068], Revenue: 381, Demand: 1
#  Product 31050116: Best Price Pair Index 56, Prices: [885 885], Revenue: 440, Demand: 1
#  Product 31050179: Best Price Pair Index 50, Prices: [4500 4500], Revenue: 1111, Demand: 1
#  Product 31050186: Best Price Pair Index 40, Prices: [2037 2037], Revenue: 0, Demand: 0
#  Product 31050260: Best Price Pair Index 42, Prices: [1668 1668], Revenue: 2725, Demand: 4
#  Product 31050261: Best Price Pair Index 56, Prices: [1740 1740], Revenue: 2132, Demand: 3
#  Product 31050297: Best Price Pair Index 56, Prices: [1628 1628], Revenue: 581, Demand: 1
#  Product 31050323: Best Price Pair Index 56, Prices: [1343 1343], Revenue: 537, Demand: 1
#  Product 31050360: Best Price Pair Index 56, Prices: [1547 1547], Revenue: 418, Demand: 1
#  Product 31050449: Best Price Pair Index 56, Prices: [1221 1221], Revenue: 349, Demand: 1
#  Product 31050458: Best Price Pair Index 49, Prices: [19938 19938], Revenue: 1329, Demand: 1
#  Product 31050534: Best Price Pair Index 56, Prices: [4254 4254], Revenue: 802, Demand: 1
#  Product 31050536: Best Price Pair Index 56, Prices: [4254 4254], Revenue: 1605, Demand: 2
#  Product 31050594: Best Price Pair Index 40, Prices: [1261 1261], Revenue: 0, Demand: 0
#  Product 31050595: Best Price Pair Index 56, Prices: [1323 1323], Revenue: 1840, Demand: 1
#  Product 31050784: Best Price Pair Index 56, Prices: [2076 2076], Revenue: 372, Demand: 1
#  Product 31050785: Best Price Pair Index 56, Prices: [2076 2076], Revenue: 305, Demand: 1
#  Product 31050797: Best Price Pair Index 56, Prices: [1618 1618], Revenue: 610, Demand: 2
#  Product 31050798: Best Price Pair Index 41, Prices: [1547 1547], Revenue: 0, Demand: 0
#  Product 31050805: Best Price Pair Index 56, Prices: [2595 2595], Revenue: 2181, Demand: 5
#  Product 31050806: Best Price Pair Index 49, Prices: [4892 4892], Revenue: 1019, Demand: 1
#  Product 31050860: Best Price Pair Index 50, Prices: [690 690], Revenue: 403, Demand: 1
#  Product 31050976: Best Price Pair Index 56, Prices: [3918 3918], Revenue: 1599, Demand: 2
#  Product 31050977: Best Price Pair Index 56, Prices: [3918 3918], Revenue: 602, Demand: 1
#  Product 31050996: Best Price Pair Index 56, Prices: [1985 1985], Revenue: 2162, Demand: 6
#  Product 31050998: Best Price Pair Index 56, Prices: [1985 1985], Revenue: 3054, Demand: 7
#  Product 31051002: Best Price Pair Index 56, Prices: [3359 3359], Revenue: 353, Demand: 1
#  Product 31051004: Best Price Pair Index 17, Prices: [2973 2973], Revenue: 0, Demand: 0
#  Product 31051005: Best Price Pair Index 50, Prices: [3299 3299], Revenue: 666, Demand: 2
#  Product 31051024: Best Price Pair Index 56, Prices: [1679 1679], Revenue: 763, Demand: 2
#  Product 31051032: Best Price Pair Index 56, Prices: [2748 2748], Revenue: 366, Demand: 1
#  Product 31051033: Best Price Pair Index 50, Prices: [2699 2699], Revenue: 385, Demand: 1
#  Product 31051034: Best Price Pair Index 50, Prices: [2699 2699], Revenue: 333, Demand: 1
#  Product 31051035: Best Price Pair Index 23, Prices: [2481 2481], Revenue: 330, Demand: 1
#  Product 31051038: Best Price Pair Index 50, Prices: [2549 2549], Revenue: 1254, Demand: 3
#  Product 31051093: Best Price Pair Index 56, Prices: [2046 2046], Revenue: 1705, Demand: 4
#  Product 31051094: Best Price Pair Index 56, Prices: [2046 2046], Revenue: 852, Demand: 2
#  Product 31051148: Best Price Pair Index 50, Prices: [3000 3000], Revenue: 383, Demand: 1
#  Product 31051165: Best Price Pair Index 50, Prices: [1800 1800], Revenue: 2250, Demand: 5
#  Product 31051356: Best Price Pair Index 56, Prices: [1782 1782], Revenue: 636, Demand: 1
#  Product 31051357: Best Price Pair Index 42, Prices: [1708 1708], Revenue: 3419, Demand: 5
#  Product 31051402: Best Price Pair Index 50, Prices: [2498 2498], Revenue: 391, Demand: 1
#  Product 31051409: Best Price Pair Index 54, Prices: [1366 1366], Revenue: 1518, Demand: 2
#  Product 31051415: Best Price Pair Index 56, Prices: [1374 1374], Revenue: 343, Demand: 1
#  Product 31051424: Best Price Pair Index 50, Prices: [3299 3299], Revenue: 330, Demand: 1
#  Product 31051425: Best Price Pair Index 56, Prices: [2198 2198], Revenue: 305, Demand: 1
#  Product 31051434: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 1321, Demand: 2
#  Product 31051435: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 1187, Demand: 2
#  Product 31051481: Best Price Pair Index 56, Prices: [1832 1832], Revenue: 399, Demand: 1
#  Product 31051491: Best Price Pair Index 56, Prices: [1502 1502], Revenue: 436, Demand: 1
#  Product 31051499: Best Price Pair Index 56, Prices: [2198 2198], Revenue: 366, Demand: 1
#  Product 31051501: Best Price Pair Index 50, Prices: [2159 2159], Revenue: 360, Demand: 1
#  Product 31051504: Best Price Pair Index 50, Prices: [2109 2109], Revenue: 428, Demand: 1
#  Product 31051505: Best Price Pair Index 50, Prices: [2109 2109], Revenue: 2597, Demand: 8
#  Product 31051512: Best Price Pair Index 50, Prices: [1476 1476], Revenue: 300, Demand: 1
#  Product 31051523: Best Price Pair Index 50, Prices: [1476 1476], Revenue: 389, Demand: 1
#  Product 31051524: Best Price Pair Index 56, Prices: [1502 1502], Revenue: 361, Demand: 1
#  Product 31051542: Best Price Pair Index 56, Prices: [2753 2753], Revenue: 559, Demand: 1
#  Product 31051543: Best Price Pair Index 56, Prices: [2753 2753], Revenue: 622, Demand: 1
#  Product 31051547: Best Price Pair Index 17, Prices: [2027 2027], Revenue: 0, Demand: 0
#  Product 31051597: Best Price Pair Index 50, Prices: [4499 4499], Revenue: 428, Demand: 1
#  Product 31051599: Best Price Pair Index 50, Prices: [4500 4500], Revenue: 360, Demand: 1
#  Product 31051600: Best Price Pair Index 17, Prices: [4054 4054], Revenue: 0, Demand: 0
#  Product 31051654: Best Price Pair Index 56, Prices: [1832 1832], Revenue: 379, Demand: 1
#  Product 31051655: Best Price Pair Index 50, Prices: [1799 1799], Revenue: 333, Demand: 1
#  Product 31051656: Best Price Pair Index 50, Prices: [1800 1800], Revenue: 500, Demand: 1
#  Product 31051678: Best Price Pair Index 56, Prices: [4758 4758], Revenue: 1335, Demand: 2
#  Product 31051694: Best Price Pair Index 50, Prices: [2549 2549], Revenue: 300, Demand: 1
#  Product 31051695: Best Price Pair Index 50, Prices: [2550 2550], Revenue: 333, Demand: 1
#  Product 31051762: Best Price Pair Index 50, Prices: [6998 6998], Revenue: 7064, Demand: 12
#  Product 31051838: Best Price Pair Index 56, Prices: [3663 3663], Revenue: 2304, Demand: 3
#  Product 31051839: Best Price Pair Index 56, Prices: [3663 3663], Revenue: 747, Demand: 1
#  Product 31051840: Best Price Pair Index 34, Prices: [3426 3426], Revenue: 2873, Demand: 4
#  Product 31051898: Best Price Pair Index 50, Prices: [360 360], Revenue: 250, Demand: 1
#  Product 31051900: Best Price Pair Index 17, Prices: [635 635], Revenue: 0, Demand: 0
#  Product 31051906: Best Price Pair Index 50, Prices: [450 450], Revenue: 250, Demand: 1
#  Product 31051907: Best Price Pair Index 17, Prices: [1081 1081], Revenue: 0, Demand: 0
#  Product 31051929: Best Price Pair Index 50, Prices: [1680 1680], Revenue: 2571, Demand: 3
#  Product 31051937: Best Price Pair Index 38, Prices: [1619 1619], Revenue: 1735, Demand: 3
#  Product 31051941: Best Price Pair Index 56, Prices: [1913 1913], Revenue: 797, Demand: 2
#  Product 31051954: Best Price Pair Index 56, Prices: [397 397], Revenue: 218, Demand: 1
#  Product 31051955: Best Price Pair Index 17, Prices: [351 351], Revenue: 0, Demand: 0
#  Product 31051962: Best Price Pair Index 17, Prices: [270 270], Revenue: 0, Demand: 0
#  Product 31051965: Best Price Pair Index 17, Prices: [189 189], Revenue: 0, Demand: 0
#  Product 31051973: Best Price Pair Index 56, Prices: [1547 1547], Revenue: 452, Demand: 1
#  Product 31051974: Best Price Pair Index 56, Prices: [1160 1160], Revenue: 305, Demand: 1
#  Product 31051982: Best Price Pair Index 56, Prices: [1913 1913], Revenue: 398, Demand: 1
#  Product 31052027: Best Price Pair Index 50, Prices: [2489 2489], Revenue: 300, Demand: 1
#  Product 31052028: Best Price Pair Index 50, Prices: [2490 2490], Revenue: 382, Demand: 1
#  Product 31052082: Best Price Pair Index 56, Prices: [1221 1221], Revenue: 321, Demand: 1
#  Product 31052083: Best Price Pair Index 56, Prices: [1221 1221], Revenue: 321, Demand: 1
#  Product 31052091: Best Price Pair Index 56, Prices: [1913 1913], Revenue: 407, Demand: 1
#  Product 31052112: Best Price Pair Index 56, Prices: [1913 1913], Revenue: 407, Demand: 1
#  Product 31052116: Best Price Pair Index 50, Prices: [2999 2999], Revenue: 522, Demand: 1
#  Product 31052118: Best Price Pair Index 50, Prices: [2999 2999], Revenue: 300, Demand: 1
#  Product 31052120: Best Price Pair Index 50, Prices: [1410 1410], Revenue: 470, Demand: 1
#  Product 31052121: Best Price Pair Index 50, Prices: [1410 1410], Revenue: 375, Demand: 1
#  Product 31052155: Best Price Pair Index 49, Prices: [8972 8972], Revenue: 997, Demand: 1
#  Product 31052156: Best Price Pair Index 50, Prices: [5398 5398], Revenue: 1499, Demand: 1
#  Product 31052240: Best Price Pair Index 56, Prices: [2738 2738], Revenue: 760, Demand: 1
#  Product 31052241: Best Price Pair Index 56, Prices: [2738 2738], Revenue: 1480, Demand: 2
#  Product 31052267: Best Price Pair Index 50, Prices: [1242 1242], Revenue: 310, Demand: 1
#  Product 31052285: Best Price Pair Index 40, Prices: [970 970], Revenue: 0, Demand: 0
#  Product 31052376: Best Price Pair Index 56, Prices: [1129 1129], Revenue: 509, Demand: 1
#  Product 31052384: Best Price Pair Index 50, Prices: [1590 1590], Revenue: 1000, Demand: 1
#  Product 31052398: Best Price Pair Index 41, Prices: [2627 2627], Revenue: 0, Demand: 0
#  Product 31052399: Best Price Pair Index 41, Prices: [2627 2627], Revenue: 0, Demand: 0
#  Product 31052400: Best Price Pair Index 17, Prices: [1432 1432], Revenue: 0, Demand: 0
#  Product 31052438: Best Price Pair Index 56, Prices: [5496 5496], Revenue: 1357, Demand: 2
#  Product 31052440: Best Price Pair Index 56, Prices: [5496 5496], Revenue: 610, Demand: 1
#  Product 31053162: Best Price Pair Index 26, Prices: [2227 2227], Revenue: 909, Demand: 2
#  Product 31053163: Best Price Pair Index 50, Prices: [2400 2400], Revenue: 528, Demand: 1
#  Product 31053174: Best Price Pair Index 36, Prices: [3065 3065], Revenue: 1415, Demand: 3
#  Product 31053175: Best Price Pair Index 56, Prices: [3257 3257], Revenue: 543, Demand: 1
#  Product 31053203: Best Price Pair Index 56, Prices: [4478 4478], Revenue: 559, Demand: 1
#  Product 31053204: Best Price Pair Index 56, Prices: [4478 4478], Revenue: 2067, Demand: 3
#  Product 31053437: Best Price Pair Index 56, Prices: [1628 1628], Revenue: 479, Demand: 1
#  Product 31053438: Best Price Pair Index 56, Prices: [1628 1628], Revenue: 509, Demand: 1
#  Product 31053439: Best Price Pair Index 56, Prices: [1628 1628], Revenue: 479, Demand: 1
#  Product 31053497: Best Price Pair Index 50, Prices: [2999 2999], Revenue: 2307, Demand: 3
#  Product 31053498: Best Price Pair Index 46, Prices: [2963 2963], Revenue: 4149, Demand: 7
#  Product 31053525: Best Price Pair Index 41, Prices: [1167 1167], Revenue: 0, Demand: 0
#  Product 31053526: Best Price Pair Index 49, Prices: [1196 1196], Revenue: 601, Demand: 1
#  Product 31054264: Best Price Pair Index 56, Prices: [1832 1832], Revenue: 407, Demand: 1
#  Product 31054272: Best Price Pair Index 50, Prices: [1799 1799], Revenue: 600, Demand: 2
#  Product 31054866: Best Price Pair Index 50, Prices: [1466 1466], Revenue: 430, Demand: 1
#  Product 31054867: Best Price Pair Index 50, Prices: [1466 1466], Revenue: 1032, Demand: 2
#  Product 31054868: Best Price Pair Index 50, Prices: [1466 1466], Revenue: 573, Demand: 1
#  Product 31054895: Best Price Pair Index 41, Prices: [1556 1556], Revenue: 0, Demand: 0
#  Product 31054896: Best Price Pair Index 40, Prices: [1552 1552], Revenue: 0, Demand: 0
#  Product 31054897: Best Price Pair Index 56, Prices: [1628 1628], Revenue: 407, Demand: 1
#  Product 31054923: Best Price Pair Index 56, Prices: [1913 1913], Revenue: 581, Demand: 1
#  Product 31054964: Best Price Pair Index 52, Prices: [1608 1608], Revenue: 3218, Demand: 4
#  Product 31054965: Best Price Pair Index 50, Prices: [1599 1599], Revenue: 799, Demand: 1
#  Product 31054970: Best Price Pair Index 50, Prices: [1200 1200], Revenue: 800, Demand: 1
#  Product 31055016: Best Price Pair Index 43, Prices: [3768 3768], Revenue: 3140, Demand: 5
#  Product 31055017: Best Price Pair Index 56, Prices: [3918 3918], Revenue: 7837, Demand: 12
#  Product 31055029: Best Price Pair Index 50, Prices: [1950 1950], Revenue: 429, Demand: 1
#  Product 31055108: Best Price Pair Index 56, Prices: [4300 4300], Revenue: 4962, Demand: 6
#  Product 31055109: Best Price Pair Index 56, Prices: [4300 4300], Revenue: 661, Demand: 1
#  Product 31055129: Best Price Pair Index 50, Prices: [2100 2100], Revenue: 403, Demand: 1
#  Product 31055158: Best Price Pair Index 57, Prices: [1020 1020], Revenue: 408, Demand: 1
#  Product 31055159: Best Price Pair Index 57, Prices: [1020 1020], Revenue: 408, Demand: 1
#  Product 31055160: Best Price Pair Index 57, Prices: [1020 1020], Revenue: 817, Demand: 2
#  Product 31055194: Best Price Pair Index 56, Prices: [3770 3770], Revenue: 2514, Demand: 3
#  Product 31055200: Best Price Pair Index 50, Prices: [3000 3000], Revenue: 352, Demand: 1
#  Product 31055310: Best Price Pair Index 56, Prices: [2442 2442], Revenue: 3355, Demand: 5
#  Product 31055314: Best Price Pair Index 56, Prices: [2798 2798], Revenue: 1231, Demand: 2
#  Product 31055315: Best Price Pair Index 56, Prices: [2798 2798], Revenue: 3078, Demand: 5
#  Product 31055343: Best Price Pair Index 56, Prices: [2034 2034], Revenue: 9311, Demand: 13
#  Product 31055352: Best Price Pair Index 50, Prices: [1110 1110], Revenue: 694, Demand: 1
#  Product 31055362: Best Price Pair Index 50, Prices: [690 690], Revenue: 428, Demand: 1
#  Product 31055363: Best Price Pair Index 50, Prices: [990 990], Revenue: 300, Demand: 1
#  Product 31055373: Best Price Pair Index 56, Prices: [4886 4886], Revenue: 1085, Demand: 2
#  Product 31055374: Best Price Pair Index 56, Prices: [4886 4886], Revenue: 977, Demand: 2
#  Product 31055416: Best Price Pair Index 50, Prices: [1813 1813], Revenue: 1451, Demand: 2
#  Product 31055417: Best Price Pair Index 56, Prices: [1846 1846], Revenue: 1477, Demand: 2
#  Product 31055490: Best Price Pair Index 50, Prices: [1998 1998], Revenue: 555, Demand: 1
#  Product 31055495: Best Price Pair Index 56, Prices: [2849 2849], Revenue: 950, Demand: 1
#  Product 31055496: Best Price Pair Index 50, Prices: [1298 1298], Revenue: 433, Demand: 1
#  Product 31055497: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 2449, Demand: 5
#  Product 31055509: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 2645, Demand: 5
#  Product 31055510: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 2116, Demand: 4
#  Product 31055521: Best Price Pair Index 50, Prices: [1649 1649], Revenue: 471, Demand: 1
#  Product 31055523: Best Price Pair Index 50, Prices: [11699 11699], Revenue: 1000, Demand: 1
#  Product 31055524: Best Price Pair Index 50, Prices: [11698 11698], Revenue: 899, Demand: 1
#  Product 31055526: Best Price Pair Index 50, Prices: [1649 1649], Revenue: 550, Demand: 1
#  Product 31055530: Best Price Pair Index 56, Prices: [1832 1832], Revenue: 1357, Demand: 1
#  Product 31055531: Best Price Pair Index 56, Prices: [1832 1832], Revenue: 555, Demand: 1
#  Product 31055542: Best Price Pair Index 56, Prices: [1832 1832], Revenue: 1110, Demand: 2
#  Product 31055552: Best Price Pair Index 50, Prices: [8998 8998], Revenue: 1199, Demand: 2
#  Product 31055554: Best Price Pair Index 50, Prices: [8998 8998], Revenue: 616, Demand: 1
#  Product 31055563: Best Price Pair Index 50, Prices: [2550 2550], Revenue: 448, Demand: 1
#  Product 31055564: Best Price Pair Index 50, Prices: [2550 2550], Revenue: 498, Demand: 1
#  Product 31055565: Best Price Pair Index 50, Prices: [2549 2549], Revenue: 392, Demand: 1
#  Product 31055599: Best Price Pair Index 56, Prices: [2900 2900], Revenue: 1289, Demand: 2
#  Product 31055600: Best Price Pair Index 56, Prices: [2900 2900], Revenue: 3223, Demand: 5
#  Product 31055603: Best Price Pair Index 56, Prices: [2320 2320], Revenue: 3516, Demand: 5
#  Product 31055604: Best Price Pair Index 56, Prices: [2320 2320], Revenue: 2442, Demand: 4
#  Product 31055630: Best Price Pair Index 56, Prices: [1902 1902], Revenue: 1189, Demand: 2
#  Product 31055631: Best Price Pair Index 50, Prices: [1869 1869], Revenue: 916, Demand: 1
#  Product 31055644: Best Price Pair Index 56, Prices: [1729 1729], Revenue: 4350, Demand: 5
#  Product 31055645: Best Price Pair Index 56, Prices: [1729 1729], Revenue: 2610, Demand: 3
#  Product 31055692: Best Price Pair Index 56, Prices: [2289 2289], Revenue: 3435, Demand: 6
#  Product 31055702: Best Price Pair Index 56, Prices: [2289 2289], Revenue: 2290, Demand: 4
#  Product 31055731: Best Price Pair Index 56, Prices: [2034 2034], Revenue: 3619, Demand: 4
#  Product 31055735: Best Price Pair Index 56, Prices: [2239 2239], Revenue: 2185, Demand: 4
#  Product 31055742: Best Price Pair Index 56, Prices: [2003 2003], Revenue: 1027, Demand: 1
#  Product 31055745: Best Price Pair Index 56, Prices: [1628 1628], Revenue: 678, Demand: 1
#  Product 31055748: Best Price Pair Index 52, Prices: [2010 2010], Revenue: 804, Demand: 1
#  Product 31055749: Best Price Pair Index 56, Prices: [1685 1685], Revenue: 479, Demand: 1
#  Product 31055750: Best Price Pair Index 56, Prices: [2321 2321], Revenue: 464, Demand: 1
#  Product 31055752: Best Price Pair Index 56, Prices: [2239 2239], Revenue: 1092, Demand: 2
#  Product 31055757: Best Price Pair Index 56, Prices: [2442 2442], Revenue: 955, Demand: 1
#  Product 31055758: Best Price Pair Index 56, Prices: [2442 2442], Revenue: 642, Demand: 1
#  Product 31055765: Best Price Pair Index 49, Prices: [7975 7975], Revenue: 3988, Demand: 4
#  Product 31055766: Best Price Pair Index 17, Prices: [1756 1756], Revenue: 0, Demand: 0
#  Product 31055767: Best Price Pair Index 56, Prices: [3257 3257], Revenue: 1221, Demand: 3
#  Product 31055768: Best Price Pair Index 56, Prices: [3307 3307], Revenue: 508, Demand: 1
#  Product 31055895: Best Price Pair Index 56, Prices: [2949 2949], Revenue: 2850, Demand: 4
#  Product 31055896: Best Price Pair Index 50, Prices: [2897 2897], Revenue: 643, Demand: 1
#  Product 31056262: Best Price Pair Index 56, Prices: [2747 2747], Revenue: 965, Demand: 1
#  Product 31056272: Best Price Pair Index 41, Prices: [1653 1653], Revenue: 0, Demand: 0
#  Product 31056273: Best Price Pair Index 50, Prices: [1699 1699], Revenue: 2317, Demand: 3
#  Product 31056274: Best Price Pair Index 50, Prices: [1699 1699], Revenue: 607, Demand: 1
#  Product 31056360: Best Price Pair Index 50, Prices: [8499 8499], Revenue: 566, Demand: 1
#  Product 31056406: Best Price Pair Index 56, Prices: [1118 1118], Revenue: 1679, Demand: 3
#  Product 31056520: Best Price Pair Index 56, Prices: [3052 3052], Revenue: 1110, Demand: 2
#  Product 31056530: Best Price Pair Index 56, Prices: [3052 3052], Revenue: 1665, Demand: 3
#  Product 31056536: Best Price Pair Index 50, Prices: [4499 4499], Revenue: 473, Demand: 1
#  Product 31056537: Best Price Pair Index 40, Prices: [3492 3492], Revenue: 367, Demand: 1
#  Product 31056539: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 2405, Demand: 4
#  Product 31056540: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 1202, Demand: 2
#  Product 31056541: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 1260, Demand: 2
#  Product 31056544: Best Price Pair Index 56, Prices: [5038 5038], Revenue: 15960, Demand: 9
#  Product 31056545: Best Price Pair Index 56, Prices: [5038 5038], Revenue: 19212, Demand: 13
#  Product 31056551: Best Price Pair Index 56, Prices: [3714 3714], Revenue: 1270, Demand: 2
#  Product 31056552: Best Price Pair Index 56, Prices: [3714 3714], Revenue: 619, Demand: 1
#  Product 31056553: Best Price Pair Index 56, Prices: [3714 3714], Revenue: 1526, Demand: 3
#  Product 31056563: Best Price Pair Index 56, Prices: [1685 1685], Revenue: 581, Demand: 1
#  Product 31056564: Best Price Pair Index 56, Prices: [1685 1685], Revenue: 1163, Demand: 2
#  Product 31056635: Best Price Pair Index 56, Prices: [1627 1627], Revenue: 1628, Demand: 2
#  Product 31056636: Best Price Pair Index 56, Prices: [1627 1627], Revenue: 1416, Demand: 2
#  Product 31056637: Best Price Pair Index 56, Prices: [1627 1627], Revenue: 2442, Demand: 3
#  Product 31056959: Best Price Pair Index 41, Prices: [3161 3161], Revenue: 486, Demand: 1
#  Product 31056960: Best Price Pair Index 50, Prices: [3248 3248], Revenue: 999, Demand: 2
#  Product 31057018: Best Price Pair Index 50, Prices: [6299 6299], Revenue: 3499, Demand: 5
#  Product 31057019: Best Price Pair Index 47, Prices: [6242 6242], Revenue: 3285, Demand: 5
#  Product 31057027: Best Price Pair Index 44, Prices: [3436 3436], Revenue: 859, Demand: 2
#  Product 31057028: Best Price Pair Index 50, Prices: [3499 3499], Revenue: 437, Demand: 1
#  Product 31057047: Best Price Pair Index 56, Prices: [3052 3052], Revenue: 1757, Demand: 2
#  Product 31057048: Best Price Pair Index 56, Prices: [3052 3052], Revenue: 1327, Demand: 2
#  Product 31057087: Best Price Pair Index 56, Prices: [4350 4350], Revenue: 6073, Demand: 3
#  Product 31057088: Best Price Pair Index 56, Prices: [4350 4350], Revenue: 3224, Demand: 2
#  Product 31057150: Best Price Pair Index 46, Prices: [6322 6322], Revenue: 3035, Demand: 3
#  Product 31057153: Best Price Pair Index 50, Prices: [1298 1298], Revenue: 649, Demand: 2
#  Product 31057154: Best Price Pair Index 50, Prices: [1298 1298], Revenue: 649, Demand: 2
#  Product 31057155: Best Price Pair Index 50, Prices: [1298 1298], Revenue: 1812, Demand: 6
#  Product 31057161: Best Price Pair Index 43, Prices: [6264 6264], Revenue: 1566, Demand: 2
#  Product 31057162: Best Price Pair Index 56, Prices: [6514 6514], Revenue: 3127, Demand: 3
#  Product 31057163: Best Price Pair Index 37, Prices: [7687 7687], Revenue: 2847, Demand: 3
#  Product 31057164: Best Price Pair Index 45, Prices: [7879 7879], Revenue: 1751, Demand: 2
#  Product 31057172: Best Price Pair Index 22, Prices: [7327 7327], Revenue: 2442, Demand: 3
#  Product 31057206: Best Price Pair Index 50, Prices: [3598 3598], Revenue: 599, Demand: 1
#  Product 31057212: Best Price Pair Index 50, Prices: [3599 3599], Revenue: 652, Demand: 1
#  Product 31057213: Best Price Pair Index 30, Prices: [3383 3383], Revenue: 1845, Demand: 3
#  Product 31057217: Best Price Pair Index 50, Prices: [999 999], Revenue: 105, Demand: 1
#  Product 31057223: Best Price Pair Index 50, Prices: [999 999], Revenue: 105, Demand: 1
#  Product 31057236: Best Price Pair Index 56, Prices: [5954 5954], Revenue: 4580, Demand: 5
#  Product 31057237: Best Price Pair Index 40, Prices: [2716 2716], Revenue: 0, Demand: 0
#  Product 31057238: Best Price Pair Index 56, Prices: [1271 1271], Revenue: 1918, Demand: 3
#  Product 31057239: Best Price Pair Index 56, Prices: [3205 3205], Revenue: 3761, Demand: 4
#  Product 31057240: Best Price Pair Index 56, Prices: [2849 2849], Revenue: 1988, Demand: 3
#  Product 31057241: Best Price Pair Index 49, Prices: [4485 4485], Revenue: 14662, Demand: 13
#  Product 31057244: Best Price Pair Index 56, Prices: [1271 1271], Revenue: 1272, Demand: 2
#  Product 31057245: Best Price Pair Index 56, Prices: [3205 3205], Revenue: 8366, Demand: 6
#  Product 31057246: Best Price Pair Index 54, Prices: [2832 2832], Revenue: 6646, Demand: 6
#  Product 31057247: Best Price Pair Index 56, Prices: [4579 4579], Revenue: 9069, Demand: 9
#  Product 31057248: Best Price Pair Index 56, Prices: [2747 2747], Revenue: 3926, Demand: 5
#  Product 31057249: Best Price Pair Index 56, Prices: [5954 5954], Revenue: 4192, Demand: 4
#  Product 31057250: Best Price Pair Index 50, Prices: [2800 2800], Revenue: 378, Demand: 1
#  Product 31057252: Best Price Pair Index 50, Prices: [11999 11999], Revenue: 1599, Demand: 2
#  Product 31057256: Best Price Pair Index 56, Prices: [1220 1220], Revenue: 1181, Demand: 3
#  Product 31057257: Best Price Pair Index 50, Prices: [1999 1999], Revenue: 850, Demand: 2
#  Product 31057258: Best Price Pair Index 50, Prices: [1999 1999], Revenue: 399, Demand: 1
#  Product 31057259: Best Price Pair Index 50, Prices: [8399 8399], Revenue: 1527, Demand: 2
#  Product 31057260: Best Price Pair Index 50, Prices: [2998 2998], Revenue: 535, Demand: 1
#  Product 31057262: Best Price Pair Index 50, Prices: [2699 2699], Revenue: 2699, Demand: 4
#  Product 31057263: Best Price Pair Index 50, Prices: [1999 1999], Revenue: 399, Demand: 1
#  Product 31057264: Best Price Pair Index 50, Prices: [8399 8399], Revenue: 1527, Demand: 2
#  Product 31057267: Best Price Pair Index 42, Prices: [975 975], Revenue: 2109, Demand: 4
#  Product 31057270: Best Price Pair Index 56, Prices: [1220 1220], Revenue: 1575, Demand: 4
#  Product 31057271: Best Price Pair Index 56, Prices: [2951 2951], Revenue: 4132, Demand: 7
#  Product 31057272: Best Price Pair Index 56, Prices: [2289 2289], Revenue: 1017, Demand: 2
#  Product 31057273: Best Price Pair Index 50, Prices: [2899 2899], Revenue: 4639, Demand: 8
#  Product 31057283: Best Price Pair Index 50, Prices: [2998 2998], Revenue: 1720, Demand: 3
#  Product 31057285: Best Price Pair Index 56, Prices: [2289 2289], Revenue: 532, Demand: 1
#  Product 31057286: Best Price Pair Index 50, Prices: [2899 2899], Revenue: 2899, Demand: 5
#  Product 31057311: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 809, Demand: 1
#  Product 31057337: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 928, Demand: 1
#  Product 31057343: Best Price Pair Index 50, Prices: [4998 4998], Revenue: 806, Demand: 1
#  Product 31057356: Best Price Pair Index 56, Prices: [2340 2340], Revenue: 1560, Demand: 2
#  Product 31057384: Best Price Pair Index 56, Prices: [1525 1525], Revenue: 1696, Demand: 2
#  Product 31057400: Best Price Pair Index 56, Prices: [1525 1525], Revenue: 763, Demand: 1
#  Product 31057403: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 661, Demand: 1
#  Product 31057419: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 601, Demand: 1
#  Product 31057425: Best Price Pair Index 56, Prices: [1322 1322], Revenue: 551, Demand: 1
#  Product 31057432: Best Price Pair Index 56, Prices: [1190 1190], Revenue: 1642, Demand: 2
#  Product 31057441: Best Price Pair Index 56, Prices: [1525 1525], Revenue: 565, Demand: 1
#  Product 31057447: Best Price Pair Index 56, Prices: [1190 1190], Revenue: 744, Demand: 1
#  Product 31057463: Best Price Pair Index 56, Prices: [1525 1525], Revenue: 1090, Demand: 1
#  Product 31057519: Best Price Pair Index 50, Prices: [9499 9499], Revenue: 1055, Demand: 1
#  Product 31057561: Best Price Pair Index 17, Prices: [8558 8558], Revenue: 0, Demand: 0
#  Product 31057579: Best Price Pair Index 50, Prices: [7599 7599], Revenue: 2171, Demand: 2
#  Product 31057580: Best Price Pair Index 50, Prices: [9499 9499], Revenue: 2111, Demand: 2
#  Product 31057581: Best Price Pair Index 32, Prices: [8986 8986], Revenue: 1797, Demand: 2
#  Product 31057589: Best Price Pair Index 50, Prices: [7599 7599], Revenue: 2171, Demand: 2
#  Product 31057590: Best Price Pair Index 50, Prices: [7599 7599], Revenue: 2171, Demand: 2
#  Product 31057592: Best Price Pair Index 50, Prices: [7598 7598], Revenue: 2026, Demand: 2
#  Product 31057594: Best Price Pair Index 56, Prices: [1648 1648], Revenue: 2908, Demand: 3
#  Product 31057598: Best Price Pair Index 56, Prices: [4579 4579], Revenue: 4071, Demand: 8
#  Product 31057603: Best Price Pair Index 33, Prices: [1536 1536], Revenue: 3843, Demand: 5
#  Product 31057607: Best Price Pair Index 56, Prices: [4579 4579], Revenue: 565, Demand: 1
#  Product 31057613: Best Price Pair Index 56, Prices: [4172 4172], Revenue: 4173, Demand: 4
#  Product 31057625: Best Price Pair Index 56, Prices: [4172 4172], Revenue: 4910, Demand: 4
#  Product 31057632: Best Price Pair Index 49, Prices: [4086 4086], Revenue: 5109, Demand: 5
#  Product 31057637: Best Price Pair Index 56, Prices: [2034 2034], Revenue: 1507, Demand: 2
#  Product 31057652: Best Price Pair Index 41, Prices: [6128 6128], Revenue: 2043, Demand: 3
#  Product 31057661: Best Price Pair Index 56, Prices: [5608 5608], Revenue: 2243, Demand: 2
#  Product 31057666: Best Price Pair Index 56, Prices: [5608 5608], Revenue: 1271, Demand: 1
#  Product 31057680: Best Price Pair Index 56, Prices: [5608 5608], Revenue: 1144, Demand: 1
#  Product 31057691: Best Price Pair Index 49, Prices: [4062 4062], Revenue: 1693, Demand: 2
#  Product 31057695: Best Price Pair Index 56, Prices: [4148 4148], Revenue: 1018, Demand: 1
#  Product 31057707: Best Price Pair Index 50, Prices: [4999 4999], Revenue: 9285, Demand: 13
#  Product 31057711: Best Price Pair Index 17, Prices: [1621 1621], Revenue: 0, Demand: 0
#  Product 31057714: Best Price Pair Index 50, Prices: [5849 5849], Revenue: 688, Demand: 1
#  Product 31057715: Best Price Pair Index 50, Prices: [4999 4999], Revenue: 9285, Demand: 13
#  Product 31057725: Best Price Pair Index 42, Prices: [2927 2927], Revenue: 2195, Demand: 3
#  Product 31057732: Best Price Pair Index 50, Prices: [3149 3149], Revenue: 2739, Demand: 2
#  Product 31057734: Best Price Pair Index 41, Prices: [1050 1050], Revenue: 0, Demand: 0
#  Product 31057735: Best Price Pair Index 50, Prices: [2998 2998], Revenue: 1764, Demand: 2
#  Product 31057737: Best Price Pair Index 50, Prices: [6299 6299], Revenue: 699, Demand: 1
#  Product 31057742: Best Price Pair Index 56, Prices: [1384 1384], Revenue: 615, Demand: 1
#  Product 31057743: Best Price Pair Index 56, Prices: [2849 2849], Revenue: 1325, Demand: 2
#  Product 31057745: Best Price Pair Index 57, Prices: [816 816], Revenue: 454, Demand: 1
#  Product 31057752: Best Price Pair Index 56, Prices: [1384 1384], Revenue: 461, Demand: 1
#  Product 31057753: Best Price Pair Index 56, Prices: [2849 2849], Revenue: 6045, Demand: 7
#  Product 31057765: Best Price Pair Index 56, Prices: [4885 4885], Revenue: 3224, Demand: 3
#  Product 31057767: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 1781, Demand: 2
#  Product 31057768: Best Price Pair Index 56, Prices: [1271 1271], Revenue: 801, Demand: 1
#  Product 31057776: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 1187, Demand: 2
#  Product 31057777: Best Price Pair Index 56, Prices: [1271 1271], Revenue: 636, Demand: 1
#  Product 31057800: Best Price Pair Index 38, Prices: [5783 5783], Revenue: 1156, Demand: 2
#  Product 31057801: Best Price Pair Index 50, Prices: [5399 5399], Revenue: 7199, Demand: 12
#  Product 31057807: Best Price Pair Index 20, Prices: [4549 4549], Revenue: 2303, Demand: 4
#  Product 31057809: Best Price Pair Index 50, Prices: [5398 5398], Revenue: 710, Demand: 1
#  Product 31057811: Best Price Pair Index 50, Prices: [5999 5999], Revenue: 599, Demand: 1
#  Product 31057856: Best Price Pair Index 41, Prices: [1653 1653], Revenue: 0, Demand: 0
#  Product 31057861: Best Price Pair Index 56, Prices: [3052 3052], Revenue: 1796, Demand: 2
#  Product 31057870: Best Price Pair Index 56, Prices: [1729 1729], Revenue: 692, Demand: 1
#  Product 31057871: Best Price Pair Index 56, Prices: [3052 3052], Revenue: 1796, Demand: 2
#  Product 31057872: Best Price Pair Index 44, Prices: [2945 2945], Revenue: 1732, Demand: 2
#  Product 31057899: Best Price Pair Index 56, Prices: [2808 2808], Revenue: 570, Demand: 1
#  Product 31057907: Best Price Pair Index 56, Prices: [2808 2808], Revenue: 570, Demand: 1
#  Product 31057908: Best Price Pair Index 56, Prices: [3004 3004], Revenue: 4458, Demand: 5
#  Product 31057909: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 1759, Demand: 2
#  Product 31057912: Best Price Pair Index 56, Prices: [3004 3004], Revenue: 610, Demand: 1
#  Product 31057913: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 1759, Demand: 2
#  Product 31057916: Best Price Pair Index 50, Prices: [4498 4498], Revenue: 562, Demand: 1
#  Product 31057947: Best Price Pair Index 46, Prices: [5927 5927], Revenue: 2540, Demand: 3
#  Product 31057948: Best Price Pair Index 56, Prices: [7633 7633], Revenue: 3817, Demand: 5
#  Product 31057953: Best Price Pair Index 56, Prices: [2340 2340], Revenue: 2229, Demand: 2
#  Product 31057958: Best Price Pair Index 56, Prices: [7633 7633], Revenue: 2290, Demand: 3
#  Product 31057959: Best Price Pair Index 56, Prices: [6106 6106], Revenue: 872, Demand: 1
#  Product 31058000: Best Price Pair Index 46, Prices: [5927 5927], Revenue: 2540, Demand: 3
#  Product 31058005: Best Price Pair Index 56, Prices: [6106 6106], Revenue: 4362, Demand: 1
#  Product 31058008: Best Price Pair Index 47, Prices: [5945 5945], Revenue: 1698, Demand: 2
#  Product 31058009: Best Price Pair Index 42, Prices: [7807 7807], Revenue: 9369, Demand: 12
#  Product 31058015: Best Price Pair Index 50, Prices: [7999 7999], Revenue: 3999, Demand: 5
#  Product 31058018: Best Price Pair Index 50, Prices: [2198 2198], Revenue: 1999, Demand: 4
#  Product 31058022: Best Price Pair Index 56, Prices: [2442 2442], Revenue: 1915, Demand: 2
#  Product 31058023: Best Price Pair Index 56, Prices: [2238 2238], Revenue: 399, Demand: 1
#  Product 31058025: Best Price Pair Index 20, Prices: [7734 7734], Revenue: 1562, Demand: 2
#  Product 31058027: Best Price Pair Index 47, Prices: [5945 5945], Revenue: 5488, Demand: 6
#  Product 31058028: Best Price Pair Index 56, Prices: [7633 7633], Revenue: 848, Demand: 1
#  Product 31058030: Best Price Pair Index 48, Prices: [2981 2981], Revenue: 3791, Demand: 4
#  Product 31058032: Best Price Pair Index 36, Prices: [8142 8142], Revenue: 2467, Demand: 3
#  Product 31058033: Best Price Pair Index 56, Prices: [6106 6106], Revenue: 4141, Demand: 4
#  Product 31058034: Best Price Pair Index 56, Prices: [7633 7633], Revenue: 1526, Demand: 2
#  Product 31058047: Best Price Pair Index 53, Prices: [3025 3025], Revenue: 1636, Demand: 2
#  Product 31058048: Best Price Pair Index 46, Prices: [4445 4445], Revenue: 2222, Demand: 3
#  Product 31058051: Best Price Pair Index 56, Prices: [3052 3052], Revenue: 3272, Demand: 3
#  Product 31058054: Best Price Pair Index 56, Prices: [4579 4579], Revenue: 1526, Demand: 2
#  Product 31058056: Best Price Pair Index 44, Prices: [2945 2945], Revenue: 3184, Demand: 4
#  Product 31058078: Best Price Pair Index 56, Prices: [5038 5038], Revenue: 8293, Demand: 4
#  Product 31058082: Best Price Pair Index 56, Prices: [5038 5038], Revenue: 1679, Demand: 2
#  Product 31058087: Best Price Pair Index 56, Prices: [5597 5597], Revenue: 2399, Demand: 3
#  Product 31058094: Best Price Pair Index 56, Prices: [5597 5597], Revenue: 799, Demand: 1
#  Product 31058675: Best Price Pair Index 49, Prices: [28413 28413], Revenue: 997, Demand: 1
#  Product 31058710: Best Price Pair Index 50, Prices: [3998 3998], Revenue: 2448, Demand: 3
#  Product 31058720: Best Price Pair Index 56, Prices: [1475 1475], Revenue: 894, Demand: 1
#  Product 31058721: Best Price Pair Index 56, Prices: [3205 3205], Revenue: 2788, Demand: 2
#  Product 31058723: Best Price Pair Index 56, Prices: [3561 3561], Revenue: 848, Demand: 1
#  Product 31058754: Best Price Pair Index 56, Prices: [4070 4070], Revenue: 1661, Demand: 2
#  Product 31058766: Best Price Pair Index 52, Prices: [5431 5431], Revenue: 3950, Demand: 4
#  Product 31058767: Best Price Pair Index 56, Prices: [5496 5496], Revenue: 999, Demand: 1
#  Product 31058847: Best Price Pair Index 56, Prices: [7124 7124], Revenue: 1131, Demand: 1
#  Product 31058868: Best Price Pair Index 56, Prices: [4885 4885], Revenue: 1177, Demand: 1
#  Product 31058869: Best Price Pair Index 43, Prices: [4649 4649], Revenue: 2847, Demand: 3
#  Product 31058879: Best Price Pair Index 56, Prices: [4885 4885], Revenue: 1200, Demand: 1
#  Product 31058887: Best Price Pair Index 56, Prices: [4834 4834], Revenue: 5482, Demand: 5
#  Product 31058896: Best Price Pair Index 47, Prices: [3467 3467], Revenue: 2497, Demand: 3
#  Product 31058905: Best Price Pair Index 56, Prices: [5801 5801], Revenue: 1934, Demand: 2
#  Product 31058922: Best Price Pair Index 31, Prices: [9429 9429], Revenue: 1905, Demand: 2
#  Product 31058923: Best Price Pair Index 56, Prices: [7328 7328], Revenue: 2058, Demand: 2
#  Product 31058928: Best Price Pair Index 56, Prices: [3205 3205], Revenue: 1603, Demand: 1
#  Product 31058932: Best Price Pair Index 56, Prices: [7328 7328], Revenue: 1272, Demand: 1
#  Product 31058937: Best Price Pair Index 50, Prices: [4999 4999], Revenue: 588, Demand: 1
#  Product 31058942: Best Price Pair Index 38, Prices: [9639 9639], Revenue: 1928, Demand: 2
#  Product 31058951: Best Price Pair Index 50, Prices: [4998 4998], Revenue: 555, Demand: 1
#  Product 31058952: Best Price Pair Index 33, Prices: [4744 4744], Revenue: 948, Demand: 2
#  Product 31058953: Best Price Pair Index 56, Prices: [3205 3205], Revenue: 1688, Demand: 1
#  Product 31058968: Best Price Pair Index 56, Prices: [7328 7328], Revenue: 1454, Demand: 1
#  Product 31058971: Best Price Pair Index 50, Prices: [9998 9998], Revenue: 6250, Demand: 5
#  Product 31058977: Best Price Pair Index 56, Prices: [4722 4722], Revenue: 1927, Demand: 2
#  Product 31058979: Best Price Pair Index 56, Prices: [6514 6514], Revenue: 3832, Demand: 4
#  Product 31058984: Best Price Pair Index 56, Prices: [7328 7328], Revenue: 927, Demand: 1
#  Product 31058986: Best Price Pair Index 56, Prices: [7328 7328], Revenue: 2952, Demand: 3
#  Product 31058988: Best Price Pair Index 50, Prices: [10798 10798], Revenue: 2117, Demand: 2
#  Product 31058989: Best Price Pair Index 56, Prices: [7328 7328], Revenue: 4886, Demand: 4
#  Product 31058992: Best Price Pair Index 50, Prices: [8999 8999], Revenue: 4525, Demand: 3
#  Product 31058993: Best Price Pair Index 56, Prices: [6514 6514], Revenue: 4299, Demand: 3
#  Product 31058997: Best Price Pair Index 56, Prices: [5088 5088], Revenue: 1197, Demand: 1
#  Product 31059004: Best Price Pair Index 56, Prices: [5088 5088], Revenue: 4072, Demand: 4
#  Product 31059053: Best Price Pair Index 56, Prices: [1281 1281], Revenue: 865, Demand: 1
#  Product 31059068: Best Price Pair Index 56, Prices: [4376 4376], Revenue: 5502, Demand: 5
#  Product 31059073: Best Price Pair Index 56, Prices: [4376 4376], Revenue: 2652, Demand: 3
#  Product 31059074: Best Price Pair Index 56, Prices: [2289 2289], Revenue: 4295, Demand: 3
#  Product 31059108: Best Price Pair Index 56, Prices: [3969 3969], Revenue: 2362, Demand: 2
#  Product 31059109: Best Price Pair Index 50, Prices: [5399 5399], Revenue: 669, Demand: 1
#  Product 31059119: Best Price Pair Index 56, Prices: [2289 2289], Revenue: 2181, Demand: 2
#  Product 31059120: Best Price Pair Index 50, Prices: [5398 5398], Revenue: 967, Demand: 1
#  Product 31059122: Best Price Pair Index 56, Prices: [3969 3969], Revenue: 882, Demand: 1
#  Product 31059139: Best Price Pair Index 41, Prices: [2334 2334], Revenue: 0, Demand: 0
#  Product 31059146: Best Price Pair Index 56, Prices: [1016 1016], Revenue: 565, Demand: 1
#  Product 31059186: Best Price Pair Index 50, Prices: [17999 17999], Revenue: 1125, Demand: 1
#  Product 31059202: Best Price Pair Index 50, Prices: [17999 17999], Revenue: 1125, Demand: 1
#  Product 31059203: Best Price Pair Index 50, Prices: [8999 8999], Revenue: 899, Demand: 1
#  Product 31059222: Best Price Pair Index 44, Prices: [5596 5596], Revenue: 932, Demand: 1
#  Product 31059240: Best Price Pair Index 56, Prices: [7633 7633], Revenue: 763, Demand: 1
#  Product 31059241: Best Price Pair Index 50, Prices: [8498 8498], Revenue: 944, Demand: 1
#  Product 31059260: Best Price Pair Index 56, Prices: [6412 6412], Revenue: 1125, Demand: 1
#  Product 31059261: Best Price Pair Index 50, Prices: [8498 8498], Revenue: 944, Demand: 1
#  Product 31059263: Best Price Pair Index 56, Prices: [7633 7633], Revenue: 779, Demand: 1

# %% [markdown]
# # new

# %% [markdown]
# # Adding INfeasibility Analysis

# %%
def initial_setup():
    folder_name= 'Experiments/July 26 Physical'
    model_names = ['CatBoostRegressor']
    date = '2024-07-26'

    inference_graphs_dir = f'{folder_name}/Inference_Graphs'  
    size = 100

    prices_list = []
    revenue_list = []
    cost_list = []
    demand_list = []
    product_ids_list = []
    national_price_creditA_list = []
    national_price_cashA_list = []
    national_price_DE_list = []
    margin_list = []
    min_credit_A_list = []
    max_credit_A_list = []
    price_segment_cluster_ls = []
    all_product_paths = []
    

    for model_name in model_names:
        base_path = os.path.join(inference_graphs_dir, model_name, '2024-07-26')
        if not os.path.exists(base_path):
            print(base_path)
            print("no")
            continue
        product_ids = os.listdir(base_path)
        for product_id in product_ids:
            try:  
                # float(product_id)
                product_dir = os.path.join(base_path, product_id)
                all_product_paths.append((product_id, product_dir))
            except ValueError:
                continue
        

    sorted_product_paths = sorted(all_product_paths)
    sorted_product_paths

    sku_map = pd.read_csv('data/sku_product_name_map.csv')
    national_price_df = pd.read_csv('data/national_price_20240722.csv',index_col=0)

    for product_id, product_dir in sorted_product_paths:
        # print(type(product_id))
        # print(product_id)
        csv_file = os.path.join(product_dir, f'{date}_uncertainty_metrics.csv')
        if os.path.exists(csv_file):
            
            df = pd.read_csv(csv_file)
            
            df = df[:size]
            
            df['Price Credit'] = df['Price Credit'].astype(int)
            df['Price Cash'] = df['Price Cash'].astype(int)
            df['Credit Prediction'] = df['Credit Prediction'].astype(int)
            df['Credit Pred Revenue'] = df['Credit Pred Revenue'].astype(int)
            # Convert pairs of 'Price Credit' and 'Price Cash' to lists
            price_pairs = [list(pair) for pair in zip(df['Price Credit'].values, df['Price Cash'].values)]
            prices_list.append(price_pairs)
            
            revenue = list(df['Credit Pred Revenue'].values)
            revenue = [int(value) for value in revenue]
            revenue_list.append(revenue)

            demand = list(df['Credit Prediction'].values)
            demand = [int(value) for value in demand]
            demand_list.append(demand)
            
            cost = list(df['Cost of Sale Credit'].values)
            cost = [abs(int(value)) for value in cost]
            cost_list.append(cost)
            
            product_ids_list.append(product_id)
            
            
            # print(len(national_price_df))
            # print('product',national_price_df[national_price_df['SKU']==str(product_id)])
            product_national_price = national_price_df[national_price_df['SKU']==int(product_id)].iloc[0]
            
            national_price_creditA = product_national_price['Control Credit Precio A']
            national_price_cashA = product_national_price['Control Cash Precio A']
            national_price_DE = product_national_price['Control Precio DE ($)']
            
            national_price_creditA_list.append(int(national_price_creditA))
            national_price_cashA_list.append(int(national_price_cashA))
            national_price_DE_list.append(int(national_price_DE))
            
            min_credit_A_list.append(int(df['Price Credit'].min()))
            max_credit_A_list.append(int(df['Price Credit'].max()))
            
            # price_segment = sku_map[sku_map['SKU']==product_id].iloc[0]
            price_segment_cluster_ls.append(product_national_price['price_segment'])

            margin = (df['Price Credit'].mean() - df['Cost of Sale Credit'].mean()) / df['Price Credit'].mean()
            margin_list.append(int(margin))  # Using mean margin for simplicity
        
            
            
            
            

    price_pair_options = [(i+1) for i in range(100)]
    # print(prices_list)

    price_array_3d = np.array([prices_list])

    prices_xr = xr.DataArray(prices_list, dims=["product", "price_pair_option", "price"], 
                                coords={"cluster":("product", price_segment_cluster_ls),
                                        "product": product_ids_list,
                                        "price_pair_option": price_pair_options
                                        }, name="Prices")
    demands_xr = xr.DataArray(demand_list, dims=["product", "price_pair_option"], 
                                coords={"product": product_ids_list, "price_pair_option": price_pair_options}, name="Demands")
    costs_xr = xr.DataArray(cost_list, dims=["product", "price_pair_option"], 
                            coords={"product": product_ids_list}, name="Costs")
    revenues_xr = xr.DataArray(revenue_list, dims=["product", "price_pair_option"], 
                                coords={"product": product_ids_list, "price_pair_option": price_pair_options}, name="Revenues")

    national_price_creditA_xr = xr.DataArray(national_price_creditA_list, dims=["product"], 
                                coords={"product": product_ids_list}, name="NationalPriceCreditA")
    
    national_price_cashA_xr = xr.DataArray(national_price_cashA_list, dims=["product"], 
                                coords={"product": product_ids_list}, name="NationalPriceCashA")

    national_price_DE_xr = xr.DataArray(national_price_DE_list, dims=["product"], 
                                coords={"product": product_ids_list}, name="NationalPriceDE")
    
    min_price_creditA_xr = xr.DataArray(min_credit_A_list, dims=["product"], 
                                coords={"product": product_ids_list}, name="MinPriceCreditA")
    max_price_creditA_xr = xr.DataArray(max_credit_A_list, dims=["product"], 
                                coords={"product": product_ids_list}, name="MaxPriceCreditA")

    margin_xr = xr.DataArray(margin_list, dims=["product"], 
                             coords={"product": product_ids_list}, name="Margins")
    
    return prices_xr, demands_xr, costs_xr, revenues_xr, national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, min_price_creditA_xr, max_price_creditA_xr, margin_xr


def generate_data_xarray(num_clusters: int, num_products_per_cluster: list, num_price_pairs: int):
    np.random.seed(0)
    
    prices_list = []
    demands_list = []
    costs_list = []
    revenues_list = []
    
    cluster_coords = []
    product_coords = []
    
    product_index = 0
    for cluster_idx in range(num_clusters):
        num_products = num_products_per_cluster[cluster_idx]
        
        prices = np.random.randint(1000, 1300, size=(num_products, num_price_pairs, 2))
        demands = np.random.randint(2000, 10000, size=(num_products, num_price_pairs))
        costs = np.random.randint(200, 500, size=(num_products, num_price_pairs))
        revenues = np.random.randint(2000, 10000, size=(num_products, num_price_pairs))
        
        prices_list.append(prices)
        demands_list.append(demands)
        costs_list.append(costs)
        revenues_list.append(revenues)
        
        cluster_coords.extend([cluster_idx + 1] * num_products)
        product_coords.extend([(product_index + i + 1) for i in range(num_products)])
        product_index += num_products
    
    prices_combined = np.concatenate(prices_list, axis=0)
    demands_combined = np.concatenate(demands_list, axis=0)
    costs_combined = np.concatenate(costs_list)
    revenues_combined = np.concatenate(revenues_list, axis=0)
    
    price_pair_options = [(i+1) for i in range(num_price_pairs)]
    
    prices_xr = xr.DataArray(prices_combined, dims=["product", "price_pair_option", "price"], 
                             coords={"cluster": ("product", cluster_coords), "product": product_coords, "price_pair_option": price_pair_options}, name="Prices")
    demands_xr = xr.DataArray(demands_combined, dims=["product", "price_pair_option"], 
                              coords={"cluster": ("product", cluster_coords), "product": product_coords, "price_pair_option": price_pair_options}, name="Demands")
    costs_xr = xr.DataArray(costs_combined, dims=["product", "price_pair_option"], 
                            coords={"cluster": ("product", cluster_coords), "product": product_coords}, name="Costs")
    
    revenues_xr = xr.DataArray(revenues_combined, dims=["product", "price_pair_option"], 
                               coords={"cluster": ("product", cluster_coords), "product": product_coords, "price_pair_option": price_pair_options}, name="Revenues")
    
    return prices_xr, demands_xr, costs_xr, revenues_xr


def define_model(prices_xr, revenues_xr, costs_xr, demands_xr,national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, margin_xr):
    num_products, num_price_pairs = prices_xr.shape[0], prices_xr.shape[1]
    price_indices = cp.intvar(0, num_price_pairs-1, shape=(num_products,), name='price_indices')
    model = cp.Model()

    add_revenue_objective(model, revenues_xr, price_indices)
    margin_constraints = add_constraints(model, prices_xr, costs_xr, price_indices, demands_xr, national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, margin_xr)

    return model, price_indices, margin_constraints


def add_revenue_objective(model: cp.Model, revenues_xr, price_indices):
    total_revenue = sum(
        cp.Element(revenues_xr.values[p, :], price_indices[p])
        for p in range(revenues_xr.shape[0])
    )
    model.maximize(total_revenue)

def add_constraints(model: cp.Model, prices_xr, costs_xr, price_indices, demands_xr,national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, margin_xr):
    
    total_cost_times_quantity = 0
    total_sale_price_times_quantity = 0
    
    for product in prices_xr.product.values:
        product_idx = prices_xr.get_index('product').get_loc(product)
        
        chosen_price = cp.Element(prices_xr.sel(product=product, price=0).values,
                              price_indices[product_idx])
        
        cost = cp.Element(costs_xr.sel(product=product).values,
                              price_indices[product_idx]) 
        quantity = cp.Element(demands_xr.sel(product=product).values,
                              price_indices[product_idx])  
        
        
        total_cost_times_quantity += cost * quantity
        total_sale_price_times_quantity += chosen_price * quantity
        
    # margin_constraint_upper = ((total_sale_price_times_quantity - total_cost_times_quantity) * 100 < 100 * total_sale_price_times_quantity)
    # model += margin_constraint_upper

    # margin_constraint_lower = ((total_sale_price_times_quantity - total_cost_times_quantity) * 100 > 1 * total_sale_price_times_quantity)
    # model += margin_constraint_lower
    
    for product in prices_xr.product.values:
        
        product_idx = prices_xr.get_index('product').get_loc(product)
        national_price_creditA = national_price_creditA_xr.sel(product=product).values
        national_price_DE  = national_price_DE_xr.sel(product=product).values
        
        model += (cp.Element(prices_xr.sel(product=product, price=0).values,
                              price_indices[product_idx]) * 100 <= national_price_creditA * 110
        )
        
        model += (cp.Element(prices_xr.sel(product=product, price=0).values,
                              price_indices[product_idx])* 100 >= national_price_creditA * 90
        )

        model += (cp.Element(prices_xr.sel(product=product, price=0).values,
                              price_indices[product_idx] )* 100  <=  national_price_DE * 95
        )
    
    # Group products by price segment
    margin_constraints = []
    
    # Group products by price segment
    price_segments = prices_xr.coords['cluster'].values
    unique_segments = np.unique(price_segments)

    for segment in unique_segments:
        segment_products = prices_xr.where(prices_xr.coords['cluster'] == segment, drop=True)
        segment_margins = margin_xr.where(prices_xr.coords['cluster'] == segment, drop=True)

        # Sort products by margin (descending order)
        sorted_indices = np.argsort(-segment_margins.values)
        sorted_products = segment_products.isel(product=sorted_indices)

        # Add constraints to ensure higher margin products have lower or equal prices
        for i in range(len(sorted_products.product) - 1):
            current_product = sorted_products.isel(product=i)
            next_product = sorted_products.isel(product=i + 1)

            current_product_index = int(np.where(prices_xr.product == current_product.product.values)[0][0])
            next_product_index = int(np.where(prices_xr.product == next_product.product.values)[0][0])

            current_price = cp.Element(prices_xr.sel(product=current_product.product.values, price=0).values, price_indices[current_product_index])
            next_price = cp.Element(prices_xr.sel(product=next_product.product.values, price=0).values, price_indices[next_product_index])

            constraint = (current_price <= next_price)
            model += constraint
            # Ensure we're storing scalar values for the product identifiers
            margin_constraints.append((constraint, current_product.product.values.item(), next_product.product.values.item()))

    return margin_constraints

def solve_model(model, price_indices, prices_xr, revenues_xr, demands_xr, national_price_creditA_xr, national_price_cashA_xr, min_price_creditA_xr, max_price_creditA_xr, national_price_DE_xr, margin_constraints):   
    ignored_products = set()
    
    while True:

        result = model.solve()
        
        if result:
            solution = pd.DataFrame(columns=['Product','Catalan Credit A','Catalan Cash A','National Credit A','National Cash A','National DE','Min Credit A','Max Credit A','Demand','Revenue'])

            
            print("Optimal total Revenue found:", model.objective_value())
            for p in range(prices_xr.shape[0]):
                price_index = price_indices[p].value()
                best_price_pair = prices_xr[p, price_index, :].values
                credit_A = prices_xr[p, price_index, 0].values
                cash_A = prices_xr[p, price_index, 1].values
                revenue = revenues_xr[p, price_index].values
                demand = demands_xr[p, price_index].values
                # cluster = prices_xr.coords['cluster'].values[p]
                product = prices_xr.coords['product'].values[p]
                natinal_credit_price = national_price_creditA_xr.sel(product=product).values
                natinal_cash_price = national_price_cashA_xr.sel(product=product).values
                min_credit_price = min_price_creditA_xr.sel(product=product).values
                max_credit_price = max_price_creditA_xr.sel(product=product).values
                national_DE_price = national_price_DE_xr.sel(product=product).values
                print(f" Product {product}: Best Price Pair Index {price_index}, Prices: {best_price_pair}, Revenue: {revenue}, Demand: {demand}")
            
                new_row = pd.DataFrame([[
                                            product,
                                            credit_A,
                                            cash_A,
                                            # best_price_pair,
                                            natinal_credit_price,
                                            natinal_cash_price,
                                            national_DE_price,
                                            min_credit_price,
                                            max_credit_price,
                                            demand,
                                            revenue
                                                ]], columns=['Product','Catalan Credit A','Catalan Cash A','National Credit A','National Cash A','National DE','Min Credit A','Max Credit A','Demand','Revenue'])
                solution = pd.concat([solution,new_row], ignore_index=True)
            
            solution.to_csv('Solution4.csv')
            
            
            if ignored_products:
                print(f"Solution found after ignoring these products for margin constraints: {ignored_products}")
            return solution
        else:
            print("No solution found. Attempting to identify and ignore problematic products for margin constraints...")
            ignored_product = find_problematic_product(model, margin_constraints)
            if ignored_product is None:
                print("Unable to identify a specific problematic product. Optimization failed.")
                return None
            
            # Ensure ignored_product is a scalar value before adding to the set
            ignored_product = ignored_product.item() if isinstance(ignored_product, np.ndarray) else ignored_product
            ignored_products.add(ignored_product)
            print(f"Ignoring product {ignored_product} for margin constraints and retrying optimization.")
            
            # Remove constraints involving the ignored product
            new_margin_constraints = []
            for constraint, prod1, prod2 in margin_constraints:
                # Ensure we're comparing scalar values
                prod1 = prod1.item() if isinstance(prod1, np.ndarray) else prod1
                prod2 = prod2.item() if isinstance(prod2, np.ndarray) else prod2
                if prod1 != ignored_product and prod2 != ignored_product:
                    new_margin_constraints.append((constraint, prod1, prod2))
                else:
                    model.remove(constraint)
            
            margin_constraints = new_margin_constraints

def find_problematic_product(model, margin_constraints):
    for constraint, prod1, prod2 in margin_constraints:
        if not constraint.value():
            # Return either product involved in the violated constraint
            # Ensure we're returning a scalar value, not an array
            return prod1.item() if isinstance(prod1, np.ndarray) else prod1
    return None



# prices_xr, demands_xr, costs_xr, revenues_xr = generate_data_xarray(num_clusters, num_products_per_cluster, num_price_options)
prices_xr, demands_xr, costs_xr, revenues_xr, national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, min_price_creditA_xr, max_price_creditA_xr, margin_xr = initial_setup()
model, price_indices, margin_constraints = define_model(prices_xr, revenues_xr, costs_xr, demands_xr, national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, margin_xr)
solution_df = solve_model(model, price_indices, prices_xr, revenues_xr, demands_xr, national_price_creditA_xr, national_price_cashA_xr, min_price_creditA_xr, max_price_creditA_xr, national_price_DE_xr, margin_constraints)
# Out:
# No solution found. Attempting to identify and ignore problematic products for margin constraints...
# Ignoring product 31051965 for margin constraints and retrying optimization.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 373
#     371 prices_xr, demands_xr, costs_xr, revenues_xr, national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, min_price_creditA_xr, max_price_creditA_xr, margin_xr = initial_setup()
#     372 model, price_indices, margin_constraints = define_model(prices_xr, revenues_xr, costs_xr, demands_xr, national_price_creditA_xr, national_price_cashA_xr, national_price_DE_xr, margin_xr)
# --> 373 solution_df = solve_model(model, price_indices, prices_xr, revenues_xr, demands_xr, national_price_creditA_xr, national_price_cashA_xr, min_price_creditA_xr, max_price_creditA_xr, national_price_DE_xr, margin_constraints)
#
# Cell In[87], line 356, in solve_model(model, price_indices, prices_xr, revenues_xr, demands_xr, national_price_creditA_xr, national_price_cashA_xr, min_price_creditA_xr, max_price_creditA_xr, national_price_DE_xr, margin_constraints)
#     354         new_margin_constraints.append((constraint, prod1, prod2))
#     355     else:
# --> 356         model.remove(constraint)
#     358 margin_constraints = new_margin_constraints
#
# AttributeError: 'Model' object has no attribute 'remove'

# %%
def select_price_for_not_priced(not_priced, date):
    products = not_priced["SKU"].values
    products

    # national_price = pd.read_csv("data/national_price_06142024.csv", index_col=0)
    predictions = pd.DataFrame()
    for product_id in products:
        print(product_id)
        filtered_row = national_price[national_price["SKU"] == int(product_id)]
        print("filtered_row", filtered_row)
        credit_A_price = filtered_row["Control Credit Precio A"].iloc[0] * 0.97

        Cash_A_price = filtered_row["Control Cash Precio A"].iloc[0] * 0.97

        new_row = pd.DataFrame(
            [
                {
                    "Date": date,
                    "SKU": product_id,
                    "Best Price Credit A": credit_A_price,
                    "Best Price Cash A": Cash_A_price,
                    "Best Price Credit DE": filtered_row["Control Precio DE ($)"].iloc[0],
                    "Best Price Cash DE": filtered_row["Control Precio DE ($)"].iloc[0],
                    # "Credit Sales Prediction": 0,
                    # "Predicted Revenue": 0,
                    # "Cost of Sale Credit": filtered_row["Cost of Sale Credit"].iloc[0],
                    # 'Actual Credit Units Sold': optimal_row['Actual Credit Units Sold'],
                    # 'Actual Cash Price A': optimal_row['Actual Scaled Cash Price'],
                    # 'Actual Credit Price A': optimal_row['Actual Scaled Credit Price'],
                    # 'Actual Revenue': optimal_row['Actual Scaled Credit Price'] * optimal_row['Actual Credit Units Sold']
                }
            ]
        )

        numeric_columns = new_row.select_dtypes(include=["number"]).columns
        print(numeric_columns)
        # new_row[numeric_columns] = new_row[numeric_columns].round(0).astype(int)
        for col in numeric_columns:
            new_row[col] = new_row[col].astype(int)

        predictions = pd.concat([predictions, new_row])
    # predictions.to_csv("final_not_priced_june21.csv")
    return predictions

df = pd.read_csv('Solution4.csv',index_col=0)
df['SKU'] = df['Product']
df["Best Price Credit A"] = df['Catalan Credit A']
df["Best Price Cash A"] = df["Catalan Cash A"]
df["Best Price Credit DE"] = df["National DE"]
df["Best Price Cash DE"] = df["National DE"]
df["Date"] = ["2024-07-30"] * len(df)
df = df.drop(['Product','Catalan Credit A',"Catalan Cash A","National DE","Min Credit A","Max Credit A","Demand","Revenue","National Credit A","National Cash A"],axis=1)
df

sku_map = pd.read_csv('data/national_price_20240722.csv')
sku_map['SKU']

national_price = pd.read_csv('data/national_price_20240726.csv')

temp = sku_map.merge(df,on='SKU', how='outer', indicator=True)
only_in_df1 = temp[temp['_merge'] == 'left_only']

not_priced_solutions = select_price_for_not_priced(only_in_df1, '2024-07-30')
not_priced_solutions

combined = pd.concat([df, not_priced_solutions])
combined.to_csv("data/predictions/07302024_EKT_Physical_Stores_Prices_Final.csv")
# Out:
# 31023696
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 506         506  Discontinuo                   1200                     1200
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 506                   3999              2757.93   0.125  31023696
#
#      price_segment
# 506              1
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31023697
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 505         505  Discontinuo                   1200                     1200
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 505                   3999              2757.93   0.125  31023697
#
#      price_segment
# 505              1
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31050521
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 508         508  Discontinuo                   4179                     4179
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 508                   7599              6100.86   0.125  31050521
#
#      price_segment
# 508              8
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31050525
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 509         509  Discontinuo                   4179                     4179
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 509                   7599              6100.86   0.125  31050525
#
#      price_segment
# 509              8
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31050968
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 510         510  Discontinuo                   3849                     3849
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 510                   6999              5583.62   0.125  31050968
#
#      price_segment
# 510              7
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31050971
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 511         511  Discontinuo                   3849                     3849
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 511                   6999              5583.62   0.125  31050971
#
#      price_segment
# 511              7
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31055383
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 507         507  Discontinuo                  19199                    19199
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 507                  23999             19290.26   0.125  31055383
#
#      price_segment
# 507             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31057523
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 504         504  Discontinuo                  19499                    19499
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 504                  23999             19290.26   0.125  31057523
#
#      price_segment
# 504             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058071
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 503         503  Discontinuo                   4949                     4949
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 503                   5499              4219.06   0.125  31058071
#
#      price_segment
# 503              8
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058639
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 497         497  Discontinuo                  25999                    25999
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 497                  25999             20897.44   0.125  31058639
#
#      price_segment
# 497             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058640
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 496         496  Discontinuo                  25999                    25999
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 496                  25999             20897.44   0.125  31058640
#
#      price_segment
# 496             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058642
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 500         500  Discontinuo                  25999                    25999
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 500                  25999             20897.44   0.125  31058642
#
#      price_segment
# 500             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058643
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 499         499  Discontinuo                  25999                    25999
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 499                  25999             20897.44   0.125  31058643
#
#      price_segment
# 499             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058652
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 498         498  Discontinuo                  21499                    21499
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 498                  21499             17281.03   0.125  31058652
#
#      price_segment
# 498             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058659
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 501         501  Discontinuo                  34999                    34999
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 501                  34999             28132.31   0.125  31058659
#
#      price_segment
# 501             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058672
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 493         493  Discontinuo                  28499                    28499
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 493                  28499             22907.69   0.125  31058672
#
#      price_segment
# 493             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058673
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 494         494  Discontinuo                  28499                    28499
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 494                  28499             22907.69   0.125  31058673
#
#      price_segment
# 494             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058674
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 492         492  Discontinuo                  28499                    28499
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 492                  28499             22907.69   0.125  31058674
#
#      price_segment
# 492             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058676
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 495         495  Discontinuo                  28499                    28499
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 495                  28499             22907.69   0.125  31058676
#
#      price_segment
# 495             10
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
# 31058894
# filtered_row      Unnamed: 0      Estatus  Control Cash Precio A  Control Credit Precio A  \
# 502         502  Discontinuo                   5699                     5699
#
#      Control Precio DE ($)  Cost of Sale Credit  Margin       SKU  \
# 502                   5999              4602.68   0.125  31058894
#
#      price_segment
# 502              9
# Index(['SKU', 'Best Price Credit A', 'Best Price Cash A',
#        'Best Price Credit DE', 'Best Price Cash DE'],
#       dtype='object')
